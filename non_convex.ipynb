# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = 3
a = 1
def f(x):
    return (y - a**2 * x**2 )**2

# %%
x = np.linspace(-5, 5)
y = f (x)
plt.plot(x, y)
plt.show()

# %%
x = np.array([3, 4])
def psi(x):
    return (x*x)

print(psi(x))
# Out:
# [ 9 16]
