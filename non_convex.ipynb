# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [0., 1.j]
0.5 * np.angle(x)
# Out:
# array([0.        , 0.78539816])

# %%
import qrcode

# URL you want to encode
url = "https://github.com/JeremieSefo/PhaseRetrievalMirror"

# Create QR code instance
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=4,
)

# Add data to the QR code
qr.add_data(url)
qr.make(fit=True)

# Create an image from the QR code
img = qr.make_image(fill='black', back_color='white')

# Save the image to a file
img.save("qrcode.png")

print("QR code generated and saved as qrcode.png")
# Out:
# QR code generated and saved as qrcode.png

# %%
import numpy as np
import matplotlib.pyplot as plt
y = 3
a = 1
rho = 100
mu = 1
def f(x):
    return 0.25 * ( a**2 * x**2 - y**2)**2
def L(x): #Gaussian
    return (0.5/rho) * ( np.abs(x) - y)**2
def l(x): #Poisson
    return  ( np.abs(x)**2 - y**2 * np.log( mu * np.abs(x)**2))
def gradf(x):
    return a**2 * x * ( a**2 * x**2 - y**2)
def hessf(x):
    return a**2 *  ( 3 * a**2 * x**2 - y**2)

# %%
x = np.linspace(-8, 8)
y1 = l (x)
y2 = gradf(x)
y3 = hessf(x)

'''
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

# Plot on the first subplot
ax1.plot(x, y1)
ax1.set_title('f(x) = 0.25 * (y**2 - a**2 * x**2 )**2')

# Plot on the second subplot
ax2.plot(x, 2 * y)
ax2.set_title('Cosine Wave')

# Adjust layout
plt.tight_layout()
plt.show()
'''


plt.plot(x, y1, label = "f(x) = 0.25 * (y**2 - a**2 * x**2 )**2")
# plt.plot(x, y2, label = "f'(x) = a**2 * x * ( a**2 * x**2 - y**2)")
# plt.plot(x, y3, label = "f''(x) = a**2 *  ( 3 * a**2 * x**2 - y**2)")
#plt.title("f(x) = 0.25 * (y**2 - a**2 * x**2 )**2")
plt.legend(loc = 'upper right')
plt.show()

# %%
x = np.array([3, 4])
def psi(x):
    return (x*x)

print(psi(x))
# Out:
# [ 9 16]
